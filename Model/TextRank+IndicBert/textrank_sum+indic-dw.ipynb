# %%
from tqdm.auto import tqdm
import pandas as pd
import numpy as np
from transformers import AutoTokenizer, AutoModelForSequenceClassification, AdamW
from torch.utils.data import Dataset
import torch
import os
import json
import re
from tqdm import tqdm
tqdm.pandas()
from transformers import Trainer, TrainingArguments
import numpy as np
from datasets import load_metric
from sklearn.model_selection import train_test_split
import ast

# %%
tokenizer = AutoTokenizer.from_pretrained("ai4bharat/indic-bert")

# %%
def model_init():
    return AutoModelForSequenceClassification.from_pretrained("ai4bharat/indic-bert", num_labels=2)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
train_df = pd.read_csv("/scratch/username/textrank_summaries/train_split_44_districts.csv")
test_df = pd.read_csv("/scratch/username/textrank_summaries/validation_split_10_districts.csv")
#train_df = train_df.head(500)
#test_df = test_df.head(500)
hp_train_df = train_df.sample(frac = 0.1, random_state=42).reset_index()
hp_test_df = test_df.sample(frac = 0.1, random_state=42).reset_index()

# %%
class LegalDataset(Dataset):
    def __init__(self, df, tokenizer):
        self.df = df.reset_index(drop=True)
        self.df["text"] = self.df["ranked-sentences"].progress_apply(lambda x:" ".join([i[1] for i in eval(x)[:10]]))
        self.df["label"] = self.df["decision"].progress_apply(lambda x:1 if x=="granted" else 0)
        self.tokenizer = tokenizer

    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
        model_input = self.df['text'][idx]            
        encoded_sent = self.tokenizer.encode_plus(
            text=model_input, 
            add_special_tokens=True,       
            max_length=512,                  
            padding='max_length',          
            return_attention_mask=True, 
            truncation=True
            )
        
        input_ids = encoded_sent.get('input_ids')
        attention_mask = encoded_sent.get('attention_mask')
        input_ids = torch.tensor(input_ids)
        attention_mask = torch.tensor(attention_mask)        

        label = torch.tensor(self.df['label'][idx])
        
        return {'input_ids': input_ids, 'attention_mask': attention_mask, 'label': label}

# %%
train_dataset = LegalDataset(train_df, tokenizer)
test_dataset = LegalDataset(test_df, tokenizer)
hp_train_dataset = LegalDataset(hp_train_df, tokenizer)
hp_test_dataset = LegalDataset(hp_test_df, tokenizer)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [00:00<00:00, 14310.44it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [00:00<00:00, 326049.75it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [00:00<00:00, 13401.10it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [00:00<00:00, 538836.59it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 13640.90it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 129774.26it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 16013.68it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 150333.48it/s]

# %%
metric1 = load_metric("accuracy")
metric2 = load_metric("f1")

# %%
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    accuracy = metric1.compute(predictions=predictions, references=labels)
    f1 = metric2.compute(predictions=predictions, references=labels, average="micro")
    return {'accuracy': accuracy["accuracy"], 'f1-score': f1["f1"]}

# %%
def my_hp_space(trial):
    return {
        "learning_rate": trial.suggest_float("learning_rate", 1e-6, 1e-4, log=True),
        "weight_decay":trial.suggest_float("weight_decay", 0.005, 0.05),
        "adam_beta1":trial.suggest_float("adam_beta1", 0.75, 0.95),
        "adam_beta2":trial.suggest_float("adam_beta2", 0.99, 0.9999),
        "adam_epsilon":trial.suggest_float("adam_epsilon", 1e-9, 1e-7, log=True)
    }

# %%
training_args = TrainingArguments(
    output_dir='/scratch/username/htr1_results',          # output directory
    num_train_epochs=5,            # total number of training epochs
    per_device_train_batch_size=8,  # batch size per device during training
    per_device_eval_batch_size=8,   # batch size for evaluation
    warmup_steps=500,               # number of warmup steps for learning rate scheduler
    weight_decay=0.01,              # strength of weight decay
    logging_dir='/scratch/username/htr1_logs',           # directory for storing logs
    evaluation_strategy="epoch",
    logging_steps=250,
    save_strategy='epoch',
    save_total_limit = 1,
    learning_rate = 0.00001,
    load_best_model_at_end=True,
    metric_for_best_model ="eval_f1-score",
)

# %%
trainer = Trainer(
    model_init=model_init,                        # the instantiated Transformers model to be trained
    args=training_args,                  # training arguments, defined above
    train_dataset=hp_train_dataset,         # training dataset
    eval_dataset=hp_test_dataset,           # evaluation dataset
    compute_metrics=compute_metrics,
    tokenizer=tokenizer,
)
# Out:
# loading configuration file https://huggingface.co/ai4bharat/indic-bert/resolve/main/config.json from cache at /home2/arjunth2001/.cache/huggingface/transformers/2d290a1a22a5f80e173def8b2f31f12d68a957542e6769ab06bfc3de06bc49f4.06ba3893e888d6ff1388c45cdbee1fb785542ae22b70ff159f55da323230a159
# Model config AlbertConfig {
#   "attention_probs_dropout_prob": 0,
#   "bos_token_id": 2,
#   "classifier_dropout_prob": 0.1,
#   "down_scale_factor": 1,
#   "embedding_size": 128,
#   "eos_token_id": 3,
#   "gap_size": 0,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "inner_group_num": 1,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "albert",
#   "net_structure_type": 0,
#   "num_attention_heads": 12,
#   "num_hidden_groups": 1,
#   "num_hidden_layers": 12,
#   "num_memory_blocks": 0,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.11.3",
#   "type_vocab_size": 2,
#   "vocab_size": 200000
# }
#
# loading weights file https://huggingface.co/ai4bharat/indic-bert/resolve/main/pytorch_model.bin from cache at /home2/arjunth2001/.cache/huggingface/transformers/b7d01f78e9854f15bcefee176019a045cae61d1cc5eb05784f961c6bc84259a2.5d565afc6c324f4805b8fa6f1750dead05eead378d1bd1b3ceb0a1f8585f6beb
# Some weights of the model checkpoint at ai4bharat/indic-bert were not used when initializing AlbertForSequenceClassification: ['predictions.dense.bias', 'predictions.bias', 'sop_classifier.classifier.weight', 'predictions.decoder.bias', 'sop_classifier.classifier.bias', 'predictions.LayerNorm.weight', 'predictions.dense.weight', 'predictions.decoder.weight', 'predictions.LayerNorm.bias']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of AlbertForSequenceClassification were not initialized from the model checkpoint at ai4bharat/indic-bert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
best_run = trainer.hyperparameter_search(n_trials=10,direction="maximize",hp_space=my_hp_space)
# Out:
# [I 2021-10-25 21:50:47,045] A new study created in memory with name: no-name-31f17326-7d63-4447-8a3f-2e7394e19e00
# Trial:
# loading configuration file https://huggingface.co/ai4bharat/indic-bert/resolve/main/config.json from cache at /home2/arjunth2001/.cache/huggingface/transformers/2d290a1a22a5f80e173def8b2f31f12d68a957542e6769ab06bfc3de06bc49f4.06ba3893e888d6ff1388c45cdbee1fb785542ae22b70ff159f55da323230a159
# Model config AlbertConfig {
#   "attention_probs_dropout_prob": 0,
#   "bos_token_id": 2,
#   "classifier_dropout_prob": 0.1,
#   "down_scale_factor": 1,
#   "embedding_size": 128,
#   "eos_token_id": 3,
#   "gap_size": 0,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "inner_group_num": 1,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "albert",
#   "net_structure_type": 0,
#   "num_attention_heads": 12,
#   "num_hidden_groups": 1,
#   "num_hidden_layers": 12,
#   "num_memory_blocks": 0,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.11.3",
#   "type_vocab_size": 2,
#   "vocab_size": 200000
# }
#
# loading weights file https://huggingface.co/ai4bharat/indic-bert/resolve/main/pytorch_model.bin from cache at /home2/arjunth2001/.cache/huggingface/transformers/b7d01f78e9854f15bcefee176019a045cae61d1cc5eb05784f961c6bc84259a2.5d565afc6c324f4805b8fa6f1750dead05eead378d1bd1b3ceb0a1f8585f6beb
# Some weights of the model checkpoint at ai4bharat/indic-bert were not used when initializing AlbertForSequenceClassification: ['predictions.dense.bias', 'predictions.bias', 'sop_classifier.classifier.weight', 'predictions.decoder.bias', 'sop_classifier.classifier.bias', 'predictions.LayerNorm.weight', 'predictions.dense.weight', 'predictions.decoder.weight', 'predictions.LayerNorm.bias']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of AlbertForSequenceClassification were not initialized from the model checkpoint at ai4bharat/indic-bert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ***** Running training *****
#   Num examples = 50
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 35
#     <div>
#
#       <progress value='35' max='35' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [35/35 00:23, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1-score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.694485</td>
#       <td>0.300000</td>
#       <td>0.300000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.694353</td>
#       <td>0.300000</td>
#       <td>0.300000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.694094</td>
#       <td>0.320000</td>
#       <td>0.320000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.693710</td>
#       <td>0.380000</td>
#       <td>0.380000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>0.693323</td>
#       <td>0.500000</td>
#       <td>0.500000</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-0/checkpoint-7
# Configuration saved in /scratch/arjunth2001/htf2_results/run-0/checkpoint-7/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-0/checkpoint-7/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-0/checkpoint-7/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-0/checkpoint-7/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-0/checkpoint-65] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-0/checkpoint-14
# Configuration saved in /scratch/arjunth2001/htf2_results/run-0/checkpoint-14/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-0/checkpoint-14/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-0/checkpoint-14/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-0/checkpoint-14/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-0/checkpoint-21
# Configuration saved in /scratch/arjunth2001/htf2_results/run-0/checkpoint-21/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-0/checkpoint-21/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-0/checkpoint-21/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-0/checkpoint-21/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-0/checkpoint-7] due to args.save_total_limit
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-0/checkpoint-14] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-0/checkpoint-28
# Configuration saved in /scratch/arjunth2001/htf2_results/run-0/checkpoint-28/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-0/checkpoint-28/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-0/checkpoint-28/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-0/checkpoint-28/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-0/checkpoint-21] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-0/checkpoint-35
# Configuration saved in /scratch/arjunth2001/htf2_results/run-0/checkpoint-35/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-0/checkpoint-35/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-0/checkpoint-35/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-0/checkpoint-35/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-0/checkpoint-28] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from /scratch/arjunth2001/htf2_results/run-0/checkpoint-35 (score: 0.5).
# [I 2021-10-25 21:51:13,905] Trial 0 finished with value: 1.0 and parameters: {'learning_rate': 4.559091455476605e-06, 'weight_decay': 0.0198080963020179, 'adam_beta1': 0.75325794085468, 'adam_beta2': 0.9979715218068316, 'adam_epsilon': 9.333052983253939e-09}. Best is trial 0 with value: 1.0.
# Trial:
# loading configuration file https://huggingface.co/ai4bharat/indic-bert/resolve/main/config.json from cache at /home2/arjunth2001/.cache/huggingface/transformers/2d290a1a22a5f80e173def8b2f31f12d68a957542e6769ab06bfc3de06bc49f4.06ba3893e888d6ff1388c45cdbee1fb785542ae22b70ff159f55da323230a159
# Model config AlbertConfig {
#   "attention_probs_dropout_prob": 0,
#   "bos_token_id": 2,
#   "classifier_dropout_prob": 0.1,
#   "down_scale_factor": 1,
#   "embedding_size": 128,
#   "eos_token_id": 3,
#   "gap_size": 0,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "inner_group_num": 1,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "albert",
#   "net_structure_type": 0,
#   "num_attention_heads": 12,
#   "num_hidden_groups": 1,
#   "num_hidden_layers": 12,
#   "num_memory_blocks": 0,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.11.3",
#   "type_vocab_size": 2,
#   "vocab_size": 200000
# }
#
# loading weights file https://huggingface.co/ai4bharat/indic-bert/resolve/main/pytorch_model.bin from cache at /home2/arjunth2001/.cache/huggingface/transformers/b7d01f78e9854f15bcefee176019a045cae61d1cc5eb05784f961c6bc84259a2.5d565afc6c324f4805b8fa6f1750dead05eead378d1bd1b3ceb0a1f8585f6beb
# Some weights of the model checkpoint at ai4bharat/indic-bert were not used when initializing AlbertForSequenceClassification: ['predictions.dense.bias', 'predictions.bias', 'sop_classifier.classifier.weight', 'predictions.decoder.bias', 'sop_classifier.classifier.bias', 'predictions.LayerNorm.weight', 'predictions.dense.weight', 'predictions.decoder.weight', 'predictions.LayerNorm.bias']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of AlbertForSequenceClassification were not initialized from the model checkpoint at ai4bharat/indic-bert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ***** Running training *****
#   Num examples = 50
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 35
#     <div>
#
#       <progress value='35' max='35' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [35/35 00:23, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1-score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.694271</td>
#       <td>0.320000</td>
#       <td>0.320000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.693534</td>
#       <td>0.380000</td>
#       <td>0.380000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.692208</td>
#       <td>0.620000</td>
#       <td>0.620000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.690582</td>
#       <td>0.720000</td>
#       <td>0.720000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>0.688655</td>
#       <td>0.720000</td>
#       <td>0.720000</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-1/checkpoint-7
# Configuration saved in /scratch/arjunth2001/htf2_results/run-1/checkpoint-7/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-1/checkpoint-7/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-1/checkpoint-7/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-1/checkpoint-7/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-1/checkpoint-65] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-1/checkpoint-14
# Configuration saved in /scratch/arjunth2001/htf2_results/run-1/checkpoint-14/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-1/checkpoint-14/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-1/checkpoint-14/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-1/checkpoint-14/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-1/checkpoint-7] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-1/checkpoint-21
# Configuration saved in /scratch/arjunth2001/htf2_results/run-1/checkpoint-21/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-1/checkpoint-21/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-1/checkpoint-21/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-1/checkpoint-21/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-1/checkpoint-14] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-1/checkpoint-28
# Configuration saved in /scratch/arjunth2001/htf2_results/run-1/checkpoint-28/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-1/checkpoint-28/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-1/checkpoint-28/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-1/checkpoint-28/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-1/checkpoint-21] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-1/checkpoint-35
# Configuration saved in /scratch/arjunth2001/htf2_results/run-1/checkpoint-35/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-1/checkpoint-35/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-1/checkpoint-35/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-1/checkpoint-35/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from /scratch/arjunth2001/htf2_results/run-1/checkpoint-28 (score: 0.72).
# [I 2021-10-25 21:51:40,048] Trial 1 finished with value: 1.44 and parameters: {'learning_rate': 2.8897392720600686e-05, 'weight_decay': 0.026866483483660025, 'adam_beta1': 0.8331169535494759, 'adam_beta2': 0.9902932231531537, 'adam_epsilon': 2.681133488124786e-09}. Best is trial 1 with value: 1.44.
# Trial:
# loading configuration file https://huggingface.co/ai4bharat/indic-bert/resolve/main/config.json from cache at /home2/arjunth2001/.cache/huggingface/transformers/2d290a1a22a5f80e173def8b2f31f12d68a957542e6769ab06bfc3de06bc49f4.06ba3893e888d6ff1388c45cdbee1fb785542ae22b70ff159f55da323230a159
# Model config AlbertConfig {
#   "attention_probs_dropout_prob": 0,
#   "bos_token_id": 2,
#   "classifier_dropout_prob": 0.1,
#   "down_scale_factor": 1,
#   "embedding_size": 128,
#   "eos_token_id": 3,
#   "gap_size": 0,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "inner_group_num": 1,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "albert",
#   "net_structure_type": 0,
#   "num_attention_heads": 12,
#   "num_hidden_groups": 1,
#   "num_hidden_layers": 12,
#   "num_memory_blocks": 0,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.11.3",
#   "type_vocab_size": 2,
#   "vocab_size": 200000
# }
#
# loading weights file https://huggingface.co/ai4bharat/indic-bert/resolve/main/pytorch_model.bin from cache at /home2/arjunth2001/.cache/huggingface/transformers/b7d01f78e9854f15bcefee176019a045cae61d1cc5eb05784f961c6bc84259a2.5d565afc6c324f4805b8fa6f1750dead05eead378d1bd1b3ceb0a1f8585f6beb
# Some weights of the model checkpoint at ai4bharat/indic-bert were not used when initializing AlbertForSequenceClassification: ['predictions.dense.bias', 'predictions.bias', 'sop_classifier.classifier.weight', 'predictions.decoder.bias', 'sop_classifier.classifier.bias', 'predictions.LayerNorm.weight', 'predictions.dense.weight', 'predictions.decoder.weight', 'predictions.LayerNorm.bias']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of AlbertForSequenceClassification were not initialized from the model checkpoint at ai4bharat/indic-bert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ***** Running training *****
#   Num examples = 50
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 35
#     <div>
#
#       <progress value='35' max='35' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [35/35 00:24, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1-score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.694482</td>
#       <td>0.300000</td>
#       <td>0.300000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.694360</td>
#       <td>0.300000</td>
#       <td>0.300000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.694128</td>
#       <td>0.320000</td>
#       <td>0.320000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.693793</td>
#       <td>0.340000</td>
#       <td>0.340000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>0.693421</td>
#       <td>0.500000</td>
#       <td>0.500000</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-2/checkpoint-7
# Configuration saved in /scratch/arjunth2001/htf2_results/run-2/checkpoint-7/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-2/checkpoint-7/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-2/checkpoint-7/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-2/checkpoint-7/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-2/checkpoint-39] due to args.save_total_limit
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-2/checkpoint-65] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-2/checkpoint-14
# Configuration saved in /scratch/arjunth2001/htf2_results/run-2/checkpoint-14/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-2/checkpoint-14/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-2/checkpoint-14/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-2/checkpoint-14/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-2/checkpoint-21
# Configuration saved in /scratch/arjunth2001/htf2_results/run-2/checkpoint-21/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-2/checkpoint-21/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-2/checkpoint-21/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-2/checkpoint-21/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-2/checkpoint-7] due to args.save_total_limit
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-2/checkpoint-14] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-2/checkpoint-28
# Configuration saved in /scratch/arjunth2001/htf2_results/run-2/checkpoint-28/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-2/checkpoint-28/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-2/checkpoint-28/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-2/checkpoint-28/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-2/checkpoint-21] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-2/checkpoint-35
# Configuration saved in /scratch/arjunth2001/htf2_results/run-2/checkpoint-35/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-2/checkpoint-35/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-2/checkpoint-35/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-2/checkpoint-35/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-2/checkpoint-28] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from /scratch/arjunth2001/htf2_results/run-2/checkpoint-35 (score: 0.5).
# [I 2021-10-25 21:52:07,106] Trial 2 finished with value: 1.0 and parameters: {'learning_rate': 4.2817685475316705e-06, 'weight_decay': 0.025014805798390872, 'adam_beta1': 0.8955421631520781, 'adam_beta2': 0.9902041709348126, 'adam_epsilon': 2.1160484426309827e-08}. Best is trial 1 with value: 1.44.
# Trial:
# loading configuration file https://huggingface.co/ai4bharat/indic-bert/resolve/main/config.json from cache at /home2/arjunth2001/.cache/huggingface/transformers/2d290a1a22a5f80e173def8b2f31f12d68a957542e6769ab06bfc3de06bc49f4.06ba3893e888d6ff1388c45cdbee1fb785542ae22b70ff159f55da323230a159
# Model config AlbertConfig {
#   "attention_probs_dropout_prob": 0,
#   "bos_token_id": 2,
#   "classifier_dropout_prob": 0.1,
#   "down_scale_factor": 1,
#   "embedding_size": 128,
#   "eos_token_id": 3,
#   "gap_size": 0,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "inner_group_num": 1,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "albert",
#   "net_structure_type": 0,
#   "num_attention_heads": 12,
#   "num_hidden_groups": 1,
#   "num_hidden_layers": 12,
#   "num_memory_blocks": 0,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.11.3",
#   "type_vocab_size": 2,
#   "vocab_size": 200000
# }
#
# loading weights file https://huggingface.co/ai4bharat/indic-bert/resolve/main/pytorch_model.bin from cache at /home2/arjunth2001/.cache/huggingface/transformers/b7d01f78e9854f15bcefee176019a045cae61d1cc5eb05784f961c6bc84259a2.5d565afc6c324f4805b8fa6f1750dead05eead378d1bd1b3ceb0a1f8585f6beb
# Some weights of the model checkpoint at ai4bharat/indic-bert were not used when initializing AlbertForSequenceClassification: ['predictions.dense.bias', 'predictions.bias', 'sop_classifier.classifier.weight', 'predictions.decoder.bias', 'sop_classifier.classifier.bias', 'predictions.LayerNorm.weight', 'predictions.dense.weight', 'predictions.decoder.weight', 'predictions.LayerNorm.bias']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of AlbertForSequenceClassification were not initialized from the model checkpoint at ai4bharat/indic-bert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ***** Running training *****
#   Num examples = 50
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 35
#     <div>
#
#       <progress value='35' max='35' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [35/35 00:23, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1-score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.694395</td>
#       <td>0.300000</td>
#       <td>0.300000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.693969</td>
#       <td>0.300000</td>
#       <td>0.300000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.693298</td>
#       <td>0.500000</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.692166</td>
#       <td>0.620000</td>
#       <td>0.620000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>0.691179</td>
#       <td>0.720000</td>
#       <td>0.720000</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-3/checkpoint-7
# Configuration saved in /scratch/arjunth2001/htf2_results/run-3/checkpoint-7/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-3/checkpoint-7/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-3/checkpoint-7/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-3/checkpoint-7/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-3/checkpoint-65] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-3/checkpoint-14
# Configuration saved in /scratch/arjunth2001/htf2_results/run-3/checkpoint-14/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-3/checkpoint-14/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-3/checkpoint-14/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-3/checkpoint-14/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-3/checkpoint-21
# Configuration saved in /scratch/arjunth2001/htf2_results/run-3/checkpoint-21/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-3/checkpoint-21/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-3/checkpoint-21/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-3/checkpoint-21/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-3/checkpoint-7] due to args.save_total_limit
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-3/checkpoint-14] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-3/checkpoint-28
# Configuration saved in /scratch/arjunth2001/htf2_results/run-3/checkpoint-28/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-3/checkpoint-28/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-3/checkpoint-28/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-3/checkpoint-28/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-3/checkpoint-21] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-3/checkpoint-35
# Configuration saved in /scratch/arjunth2001/htf2_results/run-3/checkpoint-35/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-3/checkpoint-35/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-3/checkpoint-35/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-3/checkpoint-35/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-3/checkpoint-28] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from /scratch/arjunth2001/htf2_results/run-3/checkpoint-35 (score: 0.72).
# [I 2021-10-25 21:52:33,775] Trial 3 finished with value: 1.44 and parameters: {'learning_rate': 1.5016449162511485e-05, 'weight_decay': 0.04619620824182189, 'adam_beta1': 0.8181127698510957, 'adam_beta2': 0.9986718713653312, 'adam_epsilon': 7.396492502320806e-08}. Best is trial 1 with value: 1.44.
# Trial:
# loading configuration file https://huggingface.co/ai4bharat/indic-bert/resolve/main/config.json from cache at /home2/arjunth2001/.cache/huggingface/transformers/2d290a1a22a5f80e173def8b2f31f12d68a957542e6769ab06bfc3de06bc49f4.06ba3893e888d6ff1388c45cdbee1fb785542ae22b70ff159f55da323230a159
# Model config AlbertConfig {
#   "attention_probs_dropout_prob": 0,
#   "bos_token_id": 2,
#   "classifier_dropout_prob": 0.1,
#   "down_scale_factor": 1,
#   "embedding_size": 128,
#   "eos_token_id": 3,
#   "gap_size": 0,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "inner_group_num": 1,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "albert",
#   "net_structure_type": 0,
#   "num_attention_heads": 12,
#   "num_hidden_groups": 1,
#   "num_hidden_layers": 12,
#   "num_memory_blocks": 0,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.11.3",
#   "type_vocab_size": 2,
#   "vocab_size": 200000
# }
#
# loading weights file https://huggingface.co/ai4bharat/indic-bert/resolve/main/pytorch_model.bin from cache at /home2/arjunth2001/.cache/huggingface/transformers/b7d01f78e9854f15bcefee176019a045cae61d1cc5eb05784f961c6bc84259a2.5d565afc6c324f4805b8fa6f1750dead05eead378d1bd1b3ceb0a1f8585f6beb
# Some weights of the model checkpoint at ai4bharat/indic-bert were not used when initializing AlbertForSequenceClassification: ['predictions.dense.bias', 'predictions.bias', 'sop_classifier.classifier.weight', 'predictions.decoder.bias', 'sop_classifier.classifier.bias', 'predictions.LayerNorm.weight', 'predictions.dense.weight', 'predictions.decoder.weight', 'predictions.LayerNorm.bias']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of AlbertForSequenceClassification were not initialized from the model checkpoint at ai4bharat/indic-bert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ***** Running training *****
#   Num examples = 50
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 35
#     <div>
#
#       <progress value='35' max='35' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [35/35 00:23, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1-score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.693971</td>
#       <td>0.320000</td>
#       <td>0.320000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.692540</td>
#       <td>0.600000</td>
#       <td>0.600000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.690976</td>
#       <td>0.720000</td>
#       <td>0.720000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.687419</td>
#       <td>0.720000</td>
#       <td>0.720000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>0.684166</td>
#       <td>0.720000</td>
#       <td>0.720000</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-4/checkpoint-7
# Configuration saved in /scratch/arjunth2001/htf2_results/run-4/checkpoint-7/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-4/checkpoint-7/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-4/checkpoint-7/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-4/checkpoint-7/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-4/checkpoint-65] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-4/checkpoint-14
# Configuration saved in /scratch/arjunth2001/htf2_results/run-4/checkpoint-14/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-4/checkpoint-14/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-4/checkpoint-14/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-4/checkpoint-14/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-4/checkpoint-7] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-4/checkpoint-21
# Configuration saved in /scratch/arjunth2001/htf2_results/run-4/checkpoint-21/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-4/checkpoint-21/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-4/checkpoint-21/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-4/checkpoint-21/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-4/checkpoint-14] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-4/checkpoint-28
# Configuration saved in /scratch/arjunth2001/htf2_results/run-4/checkpoint-28/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-4/checkpoint-28/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-4/checkpoint-28/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-4/checkpoint-28/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-4/checkpoint-35
# Configuration saved in /scratch/arjunth2001/htf2_results/run-4/checkpoint-35/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-4/checkpoint-35/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-4/checkpoint-35/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-4/checkpoint-35/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-4/checkpoint-28] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from /scratch/arjunth2001/htf2_results/run-4/checkpoint-21 (score: 0.72).
# [I 2021-10-25 21:53:00,237] Trial 4 finished with value: 1.44 and parameters: {'learning_rate': 6.240396137066304e-05, 'weight_decay': 0.03411355703544219, 'adam_beta1': 0.86986316960204, 'adam_beta2': 0.9929284279089637, 'adam_epsilon': 3.4981999042516665e-08}. Best is trial 1 with value: 1.44.
# Trial:
# loading configuration file https://huggingface.co/ai4bharat/indic-bert/resolve/main/config.json from cache at /home2/arjunth2001/.cache/huggingface/transformers/2d290a1a22a5f80e173def8b2f31f12d68a957542e6769ab06bfc3de06bc49f4.06ba3893e888d6ff1388c45cdbee1fb785542ae22b70ff159f55da323230a159
# Model config AlbertConfig {
#   "attention_probs_dropout_prob": 0,
#   "bos_token_id": 2,
#   "classifier_dropout_prob": 0.1,
#   "down_scale_factor": 1,
#   "embedding_size": 128,
#   "eos_token_id": 3,
#   "gap_size": 0,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "inner_group_num": 1,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "albert",
#   "net_structure_type": 0,
#   "num_attention_heads": 12,
#   "num_hidden_groups": 1,
#   "num_hidden_layers": 12,
#   "num_memory_blocks": 0,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.11.3",
#   "type_vocab_size": 2,
#   "vocab_size": 200000
# }
#
# loading weights file https://huggingface.co/ai4bharat/indic-bert/resolve/main/pytorch_model.bin from cache at /home2/arjunth2001/.cache/huggingface/transformers/b7d01f78e9854f15bcefee176019a045cae61d1cc5eb05784f961c6bc84259a2.5d565afc6c324f4805b8fa6f1750dead05eead378d1bd1b3ceb0a1f8585f6beb
# Some weights of the model checkpoint at ai4bharat/indic-bert were not used when initializing AlbertForSequenceClassification: ['predictions.dense.bias', 'predictions.bias', 'sop_classifier.classifier.weight', 'predictions.decoder.bias', 'sop_classifier.classifier.bias', 'predictions.LayerNorm.weight', 'predictions.dense.weight', 'predictions.decoder.weight', 'predictions.LayerNorm.bias']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of AlbertForSequenceClassification were not initialized from the model checkpoint at ai4bharat/indic-bert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ***** Running training *****
#   Num examples = 50
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 35
#     <div>
#
#       <progress value='35' max='35' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [35/35 00:24, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1-score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.693912</td>
#       <td>0.320000</td>
#       <td>0.320000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.692334</td>
#       <td>0.600000</td>
#       <td>0.600000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.690517</td>
#       <td>0.720000</td>
#       <td>0.720000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.686452</td>
#       <td>0.720000</td>
#       <td>0.720000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>0.682204</td>
#       <td>0.720000</td>
#       <td>0.720000</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-5/checkpoint-7
# Configuration saved in /scratch/arjunth2001/htf2_results/run-5/checkpoint-7/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-5/checkpoint-7/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-5/checkpoint-7/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-5/checkpoint-7/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-5/checkpoint-65] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-5/checkpoint-14
# Configuration saved in /scratch/arjunth2001/htf2_results/run-5/checkpoint-14/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-5/checkpoint-14/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-5/checkpoint-14/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-5/checkpoint-14/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-5/checkpoint-7] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-5/checkpoint-21
# Configuration saved in /scratch/arjunth2001/htf2_results/run-5/checkpoint-21/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-5/checkpoint-21/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-5/checkpoint-21/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-5/checkpoint-21/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-5/checkpoint-14] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-5/checkpoint-28
# Configuration saved in /scratch/arjunth2001/htf2_results/run-5/checkpoint-28/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-5/checkpoint-28/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-5/checkpoint-28/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-5/checkpoint-28/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-5/checkpoint-35
# Configuration saved in /scratch/arjunth2001/htf2_results/run-5/checkpoint-35/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-5/checkpoint-35/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-5/checkpoint-35/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-5/checkpoint-35/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-5/checkpoint-28] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from /scratch/arjunth2001/htf2_results/run-5/checkpoint-21 (score: 0.72).
# [I 2021-10-25 21:53:27,249] Trial 5 finished with value: 1.44 and parameters: {'learning_rate': 7.041190753831761e-05, 'weight_decay': 0.008204971263833313, 'adam_beta1': 0.8587713283325638, 'adam_beta2': 0.9969221212655666, 'adam_epsilon': 2.143280300047088e-08}. Best is trial 1 with value: 1.44.
# Trial:
# loading configuration file https://huggingface.co/ai4bharat/indic-bert/resolve/main/config.json from cache at /home2/arjunth2001/.cache/huggingface/transformers/2d290a1a22a5f80e173def8b2f31f12d68a957542e6769ab06bfc3de06bc49f4.06ba3893e888d6ff1388c45cdbee1fb785542ae22b70ff159f55da323230a159
# Model config AlbertConfig {
#   "attention_probs_dropout_prob": 0,
#   "bos_token_id": 2,
#   "classifier_dropout_prob": 0.1,
#   "down_scale_factor": 1,
#   "embedding_size": 128,
#   "eos_token_id": 3,
#   "gap_size": 0,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "inner_group_num": 1,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "albert",
#   "net_structure_type": 0,
#   "num_attention_heads": 12,
#   "num_hidden_groups": 1,
#   "num_hidden_layers": 12,
#   "num_memory_blocks": 0,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.11.3",
#   "type_vocab_size": 2,
#   "vocab_size": 200000
# }
#
# loading weights file https://huggingface.co/ai4bharat/indic-bert/resolve/main/pytorch_model.bin from cache at /home2/arjunth2001/.cache/huggingface/transformers/b7d01f78e9854f15bcefee176019a045cae61d1cc5eb05784f961c6bc84259a2.5d565afc6c324f4805b8fa6f1750dead05eead378d1bd1b3ceb0a1f8585f6beb
# Some weights of the model checkpoint at ai4bharat/indic-bert were not used when initializing AlbertForSequenceClassification: ['predictions.dense.bias', 'predictions.bias', 'sop_classifier.classifier.weight', 'predictions.decoder.bias', 'sop_classifier.classifier.bias', 'predictions.LayerNorm.weight', 'predictions.dense.weight', 'predictions.decoder.weight', 'predictions.LayerNorm.bias']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of AlbertForSequenceClassification were not initialized from the model checkpoint at ai4bharat/indic-bert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ...
# Model weights saved in /scratch/arjunth2001/htf2_results/run-7/checkpoint-7/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-7/checkpoint-7/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-7/checkpoint-7/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-7/checkpoint-13] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-7/checkpoint-14
# Configuration saved in /scratch/arjunth2001/htf2_results/run-7/checkpoint-14/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-7/checkpoint-14/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-7/checkpoint-14/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-7/checkpoint-14/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-7/checkpoint-7] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-7/checkpoint-21
# Configuration saved in /scratch/arjunth2001/htf2_results/run-7/checkpoint-21/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-7/checkpoint-21/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-7/checkpoint-21/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-7/checkpoint-21/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-7/checkpoint-14] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-7/checkpoint-28
# Configuration saved in /scratch/arjunth2001/htf2_results/run-7/checkpoint-28/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-7/checkpoint-28/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-7/checkpoint-28/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-7/checkpoint-28/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-7/checkpoint-35
# Configuration saved in /scratch/arjunth2001/htf2_results/run-7/checkpoint-35/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-7/checkpoint-35/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-7/checkpoint-35/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-7/checkpoint-35/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-7/checkpoint-28] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from /scratch/arjunth2001/htf2_results/run-7/checkpoint-21 (score: 0.72).
# [I 2021-10-25 21:54:20,946] Trial 7 finished with value: 1.44 and parameters: {'learning_rate': 4.44624665188372e-05, 'weight_decay': 0.048202370976977174, 'adam_beta1': 0.7993709395555981, 'adam_beta2': 0.9979875550483321, 'adam_epsilon': 1.3000323184715995e-09}. Best is trial 1 with value: 1.44.
# Trial:
# loading configuration file https://huggingface.co/ai4bharat/indic-bert/resolve/main/config.json from cache at /home2/arjunth2001/.cache/huggingface/transformers/2d290a1a22a5f80e173def8b2f31f12d68a957542e6769ab06bfc3de06bc49f4.06ba3893e888d6ff1388c45cdbee1fb785542ae22b70ff159f55da323230a159
# Model config AlbertConfig {
#   "attention_probs_dropout_prob": 0,
#   "bos_token_id": 2,
#   "classifier_dropout_prob": 0.1,
#   "down_scale_factor": 1,
#   "embedding_size": 128,
#   "eos_token_id": 3,
#   "gap_size": 0,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "inner_group_num": 1,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "albert",
#   "net_structure_type": 0,
#   "num_attention_heads": 12,
#   "num_hidden_groups": 1,
#   "num_hidden_layers": 12,
#   "num_memory_blocks": 0,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.11.3",
#   "type_vocab_size": 2,
#   "vocab_size": 200000
# }
#
# loading weights file https://huggingface.co/ai4bharat/indic-bert/resolve/main/pytorch_model.bin from cache at /home2/arjunth2001/.cache/huggingface/transformers/b7d01f78e9854f15bcefee176019a045cae61d1cc5eb05784f961c6bc84259a2.5d565afc6c324f4805b8fa6f1750dead05eead378d1bd1b3ceb0a1f8585f6beb
# Some weights of the model checkpoint at ai4bharat/indic-bert were not used when initializing AlbertForSequenceClassification: ['predictions.dense.bias', 'predictions.bias', 'sop_classifier.classifier.weight', 'predictions.decoder.bias', 'sop_classifier.classifier.bias', 'predictions.LayerNorm.weight', 'predictions.dense.weight', 'predictions.decoder.weight', 'predictions.LayerNorm.bias']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of AlbertForSequenceClassification were not initialized from the model checkpoint at ai4bharat/indic-bert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ***** Running training *****
#   Num examples = 50
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 35
#     <div>
#
#       <progress value='35' max='35' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [35/35 00:24, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1-score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.694162</td>
#       <td>0.340000</td>
#       <td>0.340000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.693084</td>
#       <td>0.480000</td>
#       <td>0.480000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.691242</td>
#       <td>0.720000</td>
#       <td>0.720000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.688903</td>
#       <td>0.720000</td>
#       <td>0.720000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>0.686309</td>
#       <td>0.720000</td>
#       <td>0.720000</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-8/checkpoint-7
# Configuration saved in /scratch/arjunth2001/htf2_results/run-8/checkpoint-7/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-8/checkpoint-7/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-8/checkpoint-7/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-8/checkpoint-7/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-8/checkpoint-13] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-8/checkpoint-14
# Configuration saved in /scratch/arjunth2001/htf2_results/run-8/checkpoint-14/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-8/checkpoint-14/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-8/checkpoint-14/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-8/checkpoint-14/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-8/checkpoint-7] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-8/checkpoint-21
# Configuration saved in /scratch/arjunth2001/htf2_results/run-8/checkpoint-21/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-8/checkpoint-21/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-8/checkpoint-21/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-8/checkpoint-21/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-8/checkpoint-14] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-8/checkpoint-28
# Configuration saved in /scratch/arjunth2001/htf2_results/run-8/checkpoint-28/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-8/checkpoint-28/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-8/checkpoint-28/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-8/checkpoint-28/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-8/checkpoint-35
# Configuration saved in /scratch/arjunth2001/htf2_results/run-8/checkpoint-35/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-8/checkpoint-35/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-8/checkpoint-35/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-8/checkpoint-35/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-8/checkpoint-28] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from /scratch/arjunth2001/htf2_results/run-8/checkpoint-21 (score: 0.72).
# [I 2021-10-25 21:54:48,225] Trial 8 finished with value: 1.44 and parameters: {'learning_rate': 4.332610468911615e-05, 'weight_decay': 0.035589164469419524, 'adam_beta1': 0.7949982193614052, 'adam_beta2': 0.9969196305877832, 'adam_epsilon': 1.7843983251568345e-09}. Best is trial 1 with value: 1.44.
# Trial:
# loading configuration file https://huggingface.co/ai4bharat/indic-bert/resolve/main/config.json from cache at /home2/arjunth2001/.cache/huggingface/transformers/2d290a1a22a5f80e173def8b2f31f12d68a957542e6769ab06bfc3de06bc49f4.06ba3893e888d6ff1388c45cdbee1fb785542ae22b70ff159f55da323230a159
# Model config AlbertConfig {
#   "attention_probs_dropout_prob": 0,
#   "bos_token_id": 2,
#   "classifier_dropout_prob": 0.1,
#   "down_scale_factor": 1,
#   "embedding_size": 128,
#   "eos_token_id": 3,
#   "gap_size": 0,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "inner_group_num": 1,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "albert",
#   "net_structure_type": 0,
#   "num_attention_heads": 12,
#   "num_hidden_groups": 1,
#   "num_hidden_layers": 12,
#   "num_memory_blocks": 0,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.11.3",
#   "type_vocab_size": 2,
#   "vocab_size": 200000
# }
#
# loading weights file https://huggingface.co/ai4bharat/indic-bert/resolve/main/pytorch_model.bin from cache at /home2/arjunth2001/.cache/huggingface/transformers/b7d01f78e9854f15bcefee176019a045cae61d1cc5eb05784f961c6bc84259a2.5d565afc6c324f4805b8fa6f1750dead05eead378d1bd1b3ceb0a1f8585f6beb
# Some weights of the model checkpoint at ai4bharat/indic-bert were not used when initializing AlbertForSequenceClassification: ['predictions.dense.bias', 'predictions.bias', 'sop_classifier.classifier.weight', 'predictions.decoder.bias', 'sop_classifier.classifier.bias', 'predictions.LayerNorm.weight', 'predictions.dense.weight', 'predictions.decoder.weight', 'predictions.LayerNorm.bias']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of AlbertForSequenceClassification were not initialized from the model checkpoint at ai4bharat/indic-bert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ***** Running training *****
#   Num examples = 50
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 35
#     <div>
#
#       <progress value='22' max='35' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [22/35 00:11 < 00:07, 1.68 it/s, Epoch 3/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1-score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.694152</td>
#       <td>0.340000</td>
#       <td>0.340000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.693174</td>
#       <td>0.500000</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.691460</td>
#       <td>0.700000</td>
#       <td>0.700000</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-9/checkpoint-7
# Configuration saved in /scratch/arjunth2001/htf2_results/run-9/checkpoint-7/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-9/checkpoint-7/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-9/checkpoint-7/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-9/checkpoint-7/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-9/checkpoint-26] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# Saving model checkpoint to /scratch/arjunth2001/htf2_results/run-9/checkpoint-14
# Configuration saved in /scratch/arjunth2001/htf2_results/run-9/checkpoint-14/config.json
# Model weights saved in /scratch/arjunth2001/htf2_results/run-9/checkpoint-14/pytorch_model.bin
# tokenizer config file saved in /scratch/arjunth2001/htf2_results/run-9/checkpoint-14/tokenizer_config.json
# Special tokens file saved in /scratch/arjunth2001/htf2_results/run-9/checkpoint-14/special_tokens_map.json
# Deleting older checkpoint [/scratch/arjunth2001/htf2_results/run-9/checkpoint-7] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 8
# [I 2021-10-25 21:55:04,028] Trial 9 pruned.

# %%
print("Best HyperParameters")
# Out:
# Best HyperParameters

# %%
print(best_run)
# Out:
# BestRun(run_id='1', objective=1.44, hyperparameters={'learning_rate': 2.8897392720600686e-05, 'weight_decay': 0.026866483483660025, 'adam_beta1': 0.8331169535494759, 'adam_beta2': 0.9902932231531537, 'adam_epsilon': 2.681133488124786e-09})

# %%
del trainer
del training_args
import gc
gc.collect()
# Out:
# 187

# %%
print("Starting Training...")
# Out:
# Starting Training...

# %%
training_args = TrainingArguments(
    output_dir='/scratch/username/tr1_results',          # output directory
    num_train_epochs=15,            # total number of training epochs
    per_device_train_batch_size=8,  # batch size per device during training
    per_device_eval_batch_size=8,   # batch size for evaluation
    warmup_steps=500,               # number of warmup steps for learning rate scheduler
    weight_decay=0.01,              # strength of weight decay
    logging_dir='/scratch/username/tr1_logs',           # directory for storing logs
    evaluation_strategy="epoch",
    logging_steps=250,
    save_strategy='epoch',
    save_total_limit = 1,
    learning_rate = 0.00001,
    load_best_model_at_end=True,
    metric_for_best_model ="eval_f1-score",
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
trainer = Trainer(
    model_init=model_init,                        # the instantiated Transformers model to be trained
    args=training_args,                  # training arguments, defined above
    train_dataset=train_dataset,         # training dataset
    eval_dataset=test_dataset,           # evaluation dataset
    compute_metrics=compute_metrics,
    tokenizer=tokenizer,
)
# Out:
# loading configuration file https://huggingface.co/ai4bharat/indic-bert/resolve/main/config.json from cache at /home2/arjunth2001/.cache/huggingface/transformers/2d290a1a22a5f80e173def8b2f31f12d68a957542e6769ab06bfc3de06bc49f4.06ba3893e888d6ff1388c45cdbee1fb785542ae22b70ff159f55da323230a159
# Model config AlbertConfig {
#   "attention_probs_dropout_prob": 0,
#   "bos_token_id": 2,
#   "classifier_dropout_prob": 0.1,
#   "down_scale_factor": 1,
#   "embedding_size": 128,
#   "eos_token_id": 3,
#   "gap_size": 0,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "inner_group_num": 1,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "albert",
#   "net_structure_type": 0,
#   "num_attention_heads": 12,
#   "num_hidden_groups": 1,
#   "num_hidden_layers": 12,
#   "num_memory_blocks": 0,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.11.3",
#   "type_vocab_size": 2,
#   "vocab_size": 200000
# }
#
# loading weights file https://huggingface.co/ai4bharat/indic-bert/resolve/main/pytorch_model.bin from cache at /home2/arjunth2001/.cache/huggingface/transformers/b7d01f78e9854f15bcefee176019a045cae61d1cc5eb05784f961c6bc84259a2.5d565afc6c324f4805b8fa6f1750dead05eead378d1bd1b3ceb0a1f8585f6beb
# Some weights of the model checkpoint at ai4bharat/indic-bert were not used when initializing AlbertForSequenceClassification: ['predictions.dense.bias', 'predictions.bias', 'sop_classifier.classifier.weight', 'predictions.decoder.bias', 'sop_classifier.classifier.bias', 'predictions.LayerNorm.weight', 'predictions.dense.weight', 'predictions.decoder.weight', 'predictions.LayerNorm.bias']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of AlbertForSequenceClassification were not initialized from the model checkpoint at ai4bharat/indic-bert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
for n, v in best_run.hyperparameters.items():
    setattr(trainer.args, n, v)
print(trainer.args)
trainer.train()
# Out:
# TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.8331169535494759,
# adam_beta2=0.9902932231531537,
# adam_epsilon=2.681133488124786e-09,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_find_unused_parameters=None,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=False,
# do_train=False,
# eval_accumulation_steps=None,
# eval_steps=None,
# evaluation_strategy=IntervalStrategy.EPOCH,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# greater_is_better=True,
# group_by_length=False,
# hub_model_id=None,
# hub_strategy=HubStrategy.EVERY_SAVE,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=2.8897392720600686e-05,
# length_column_name=length,
# load_best_model_at_end=True,
# local_rank=-1,
# log_level=-1,
# log_level_replica=-1,
# log_on_each_node=True,
# logging_dir=/scratch/arjunth2001/tf2_logs,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=250,
# logging_strategy=IntervalStrategy.STEPS,
# lr_scheduler_type=SchedulerType.LINEAR,
# max_grad_norm=1.0,
# max_steps=-1,
# metric_for_best_model=eval_f1-score,
# mp_parameters=,
# no_cuda=False,
# num_train_epochs=15,
# output_dir=/scratch/arjunth2001/tf2_results,
# overwrite_output_dir=False,
# past_index=-1,
# per_device_eval_batch_size=8,
# per_device_train_batch_size=8,
# prediction_loss_only=False,
# push_to_hub=False,
# push_to_hub_model_id=None,
# push_to_hub_organization=None,
# push_to_hub_token=<PUSH_TO_HUB_TOKEN>,
# remove_unused_columns=True,
# report_to=[],
# resume_from_checkpoint=None,
# run_name=/scratch/arjunth2001/tf2_results,
# save_on_each_node=False,
# save_steps=500,
# save_strategy=IntervalStrategy.EPOCH,
# save_total_limit=1,
# seed=42,
# sharded_ddp=[],
# skip_memory_metrics=True,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# use_legacy_prediction_loop=False,
# warmup_ratio=0.0,
# warmup_steps=500,
# weight_decay=0.026866483483660025,
# xpu_backend=None,
# )
# loading configuration file https://huggingface.co/ai4bharat/indic-bert/resolve/main/config.json from cache at /home2/arjunth2001/.cache/huggingface/transformers/2d290a1a22a5f80e173def8b2f31f12d68a957542e6769ab06bfc3de06bc49f4.06ba3893e888d6ff1388c45cdbee1fb785542ae22b70ff159f55da323230a159
# Model config AlbertConfig {
#   "attention_probs_dropout_prob": 0,
#   "bos_token_id": 2,
#   "classifier_dropout_prob": 0.1,
#   "down_scale_factor": 1,
#   "embedding_size": 128,
#   "eos_token_id": 3,
#   "gap_size": 0,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "inner_group_num": 1,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "albert",
#   "net_structure_type": 0,
#   "num_attention_heads": 12,
#   "num_hidden_groups": 1,
#   "num_hidden_layers": 12,
#   "num_memory_blocks": 0,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.11.3",
#   "type_vocab_size": 2,
#   "vocab_size": 200000
# }
#
# loading weights file https://huggingface.co/ai4bharat/indic-bert/resolve/main/pytorch_model.bin from cache at /home2/arjunth2001/.cache/huggingface/transformers/b7d01f78e9854f15bcefee176019a045cae61d1cc5eb05784f961c6bc84259a2.5d565afc6c324f4805b8fa6f1750dead05eead378d1bd1b3ceb0a1f8585f6beb
# Some weights of the model checkpoint at ai4bharat/indic-bert were not used when initializing AlbertForSequenceClassification: ['predictions.dense.bias', 'predictions.bias', 'sop_classifier.classifier.weight', 'predictions.decoder.bias', 'sop_classifier.classifier.bias', 'predictions.LayerNorm.weight', 'predictions.dense.weight', 'predictions.decoder.weight', 'predictions.LayerNorm.bias']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of AlbertForSequenceClassification were not initialized from the model checkpoint at ai4bharat/indic-bert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ***** Running training *****
#   Num examples = 500
#   Num Epochs = 15
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 945
#     <div>
#
#       <progress value='64' max='945' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 64/945 00:25 < 05:56, 2.47 it/s, Epoch 1/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='41' max='63' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [41/63 00:06 < 00:03, 6.18 it/s]
#     </div>
# ***** Running Evaluation *****
#   Num examples = 500
#   Batch size = 8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_5301/2684222838.py in <module>
#       2     setattr(trainer.args, n, v)
#       3 print(trainer.args)
# ----> 4 trainer.train()
#
# ~/miniconda3/envs/legal/lib/python3.7/site-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1389
#    1390             self.control = self.callback_handler.on_epoch_end(args, self.state, self.control)
# -> 1391             self._maybe_log_save_evaluate(tr_loss, model, trial, epoch, ignore_keys_for_eval)
#    1392
#    1393             if DebugOption.TPU_METRICS_DEBUG in self.args.debug:
#
# ~/miniconda3/envs/legal/lib/python3.7/site-packages/transformers/trainer.py in _maybe_log_save_evaluate(self, tr_loss, model, trial, epoch, ignore_keys_for_eval)
#    1489         metrics = None
#    1490         if self.control.should_evaluate:
# -> 1491             metrics = self.evaluate(ignore_keys=ignore_keys_for_eval)
#    1492             self._report_to_hp_search(trial, epoch, metrics)
#    1493
#
# ~/miniconda3/envs/legal/lib/python3.7/site-packages/transformers/trainer.py in evaluate(self, eval_dataset, ignore_keys, metric_key_prefix)
#    2118             prediction_loss_only=True if self.compute_metrics is None else None,
#    2119             ignore_keys=ignore_keys,
# -> 2120             metric_key_prefix=metric_key_prefix,
#    2121         )
#    2122
#
# ~/miniconda3/envs/legal/lib/python3.7/site-packages/transformers/trainer.py in evaluation_loop(self, dataloader, description, prediction_loss_only, ignore_keys, metric_key_prefix)
#    2283
#    2284             # Prediction step
# -> 2285             loss, logits, labels = self.prediction_step(model, inputs, prediction_loss_only, ignore_keys=ignore_keys)
#    2286
#    2287             # Update containers on host
#
# ~/miniconda3/envs/legal/lib/python3.7/site-packages/transformers/trainer.py in prediction_step(self, model, inputs, prediction_loss_only, ignore_keys)
#    2487             else:
#    2488                 if has_labels:
# -> 2489                     loss, outputs = self.compute_loss(model, inputs, return_outputs=True)
#    2490                     loss = loss.mean().detach()
#    2491                     if isinstance(outputs, dict):
#
# ~/miniconda3/envs/legal/lib/python3.7/site-packages/transformers/trainer.py in compute_loss(self, model, inputs, return_outputs)
#    1879         else:
#    1880             labels = None
# -> 1881         outputs = model(**inputs)
#    1882         # Save past state if it exists
#    1883         # TODO: this needs to be fixed and made cleaner later.
#
# ~/miniconda3/envs/legal/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniconda3/envs/legal/lib/python3.7/site-packages/transformers/models/albert/modeling_albert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1032             output_attentions=output_attentions,
#    1033             output_hidden_states=output_hidden_states,
# -> 1034             return_dict=return_dict,
#    1035         )
#    1036
#
# ~/miniconda3/envs/legal/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniconda3/envs/legal/lib/python3.7/site-packages/transformers/models/albert/modeling_albert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     726             output_attentions=output_attentions,
#     727             output_hidden_states=output_hidden_states,
# --> 728             return_dict=return_dict,
#     729         )
#     730
#
# ~/miniconda3/envs/legal/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniconda3/envs/legal/lib/python3.7/site-packages/transformers/models/albert/modeling_albert.py in forward(self, hidden_states, attention_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#     471                 head_mask[group_idx * layers_per_group : (group_idx + 1) * layers_per_group],
#     472                 output_attentions,
# --> 473                 output_hidden_states,
#     474             )
#     475             hidden_states = layer_group_output[0]
#
# ~/miniconda3/envs/legal/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniconda3/envs/legal/lib/python3.7/site-packages/transformers/models/albert/modeling_albert.py in forward(self, hidden_states, attention_mask, head_mask, output_attentions, output_hidden_states)
#     418
#     419         for layer_index, albert_layer in enumerate(self.albert_layers):
# --> 420             layer_output = albert_layer(hidden_states, attention_mask, head_mask[layer_index], output_attentions)
#     421             hidden_states = layer_output[0]
#     422
#
# ~/miniconda3/envs/legal/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniconda3/envs/legal/lib/python3.7/site-packages/transformers/models/albert/modeling_albert.py in forward(self, hidden_states, attention_mask, head_mask, output_attentions, output_hidden_states)
#     386         self, hidden_states, attention_mask=None, head_mask=None, output_attentions=False, output_hidden_states=False
#     387     ):
# --> 388         attention_output = self.attention(hidden_states, attention_mask, head_mask, output_attentions)
#     389
#     390         ffn_output = apply_chunking_to_forward(
#
# ~/miniconda3/envs/legal/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniconda3/envs/legal/lib/python3.7/site-packages/transformers/models/albert/modeling_albert.py in forward(self, hidden_states, attention_mask, head_mask, output_attentions)
#     326
#     327         # Take the dot product between "query" and "key" to get the raw attention scores.
# --> 328         attention_scores = torch.matmul(query_layer, key_layer.transpose(-1, -2))
#     329         attention_scores = attention_scores / math.sqrt(self.attention_head_size)
#     330
#
# KeyboardInterrupt:

# %%
trainer.save_model("/home2/username/legal-tech/textrank_sum+indic-dw")
